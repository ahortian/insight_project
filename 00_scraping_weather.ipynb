# %% [markdown]
# # Scraping weather data
#
#
# This notebook scrap the historical daily weather information from https://www.wunderground.com/history/daily/. The procedure is the following.
#
# 1. Select range of date and for each day put the day into get_data_n_soup function.
#
# 2. Inside the get_data_n_soup
#     - Ask Selenium to open the website, and execute inner javascript.
#     - Parse data into beautifulsoup object and look for the hourly table
#     - Parse the table into a panda dataframe
#     - remove the unit
#     - add date column
#
#
# 3. Use beautifulsoup to extract the unit in get_unit function.
# 4. Add unit into Pandas columns name
# 5. Combine each df from daily table into a single dataframe and save it.
#
# Reference:
# - http://stanford.edu/~mgorkove/cgi-bin/rpython_tutorials/Scraping_a_Webpage_Rendered_by_Javascript_Using_Python.php
# - https://automatetheboringstuff.com/chapter11/

# %%
import sys
import wget
import requests
from pathlib import Path
from fastai.imports import *
from bs4 import BeautifulSoup
from selenium import webdriver 
from datetime import datetime, date
import time
import pandas as pd

# %% [markdown]
# ## Testing the Scraper

# %%
# set path to chromedriver
driver_path = "./chrome_driver/chromedriver"
browser = webdriver.Chrome(driver_path)

# %%
# select date range 
start_date = datetime(2018, 8, 26)
stop_date = datetime(2018, 8, 26)
# convert date-time object to string
date_range = pd.date_range(start_date, stop_date).strftime('%Y-%m-%d')
#select one date
date_str = date_range[0]
#date_str = '2018-08-26'

# %%
# for now use the station KBOS weather station at airport
url=f'https://www.wunderground.com/history/daily/us/ma/boston/KBOS/date/{date_str}'

# %%
# open the website
browser.get(url)
time.sleep(10)

# execute inner html 
innerhtml= browser.execute_script("return document.body.innerHTML")

# parse html into beautifulsoup object
soup = BeautifulSoup(innerhtml)

# %%
# find the hourly weather report  

# This worked in June 2019
#div_table=soup.find_all(attrs={"id": "history-observation-table"})[0] # 

# Update code Jan 2020
div_table=soup.find_all(attrs={"class":"observation-table ng-star-inserted"})[0]

# %%
#parse into a panda dataframe
daily_df = pd.read_html(str(div_table))[0]
daily_df
# Out:
#        Time Temperature Dew Point Humidity Wind Wind Speed Wind Gust  \
# 0   6:54 PM        76 F      66 F     71 %    S     12 mph     0 mph
# 1   7:54 PM        75 F      67 F     76 %    S     12 mph     0 mph
# 2   9:54 PM        75 F      67 F     76 %   SW     10 mph     0 mph
# 3  10:54 PM        74 F      67 F     79 %  WSW     10 mph     0 mph
#
#    Pressure Precip.      Condition
# 0  29.99 in  0.0 in           Fair
# 1  29.99 in  0.0 in           Fair
# 2  29.99 in  0.0 in           Fair
# 3  30.00 in  0.0 in  Partly Cloudy

# %%
# add unit into header
trow = div_table.tbody.find_all('tr')

 #stripping unit
f_row = trow[0]
units=[]
for unit_cell in f_row.find_all(class_="wu-label"):
    unit = ''.join(string for string in unit_cell.stripped_strings)
    units.append(r'('+unit+r')')
units.insert(0, '')
units.insert(4, '')
units.append('')

# %%
daily_df.columns + units
# Out:
# Index(['Time', 'Temperature(F)', 'Dew Point(F)', 'Humidity(%)', 'Wind',
#        'Wind Speed(mph)', 'Wind Gust(mph)', 'Pressure(in)', 'Precip.(in)',
#        'Condition'],
#       dtype='object')

# %%
daily_df.columns = daily_df.columns + units
daily_df.head()
# Out:
#        Time Temperature(F) Dew Point(F) Humidity(%) Wind Wind Speed(mph)  \
# 0   6:54 PM           76 F         66 F        71 %    S          12 mph
# 1   7:54 PM           75 F         67 F        76 %    S          12 mph
# 2   9:54 PM           75 F         67 F        76 %   SW          10 mph
# 3  10:54 PM           74 F         67 F        79 %  WSW          10 mph
#
#   Wind Gust(mph) Pressure(in) Precip.(in)      Condition
# 0          0 mph     29.99 in      0.0 in           Fair
# 1          0 mph     29.99 in      0.0 in           Fair
# 2          0 mph     29.99 in      0.0 in           Fair
# 3          0 mph     30.00 in      0.0 in  Partly Cloudy

# %%
# clean up data
daily_df.iloc[:,1] = daily_df.iloc[:,1].str.replace('\xa0F','')
daily_df.iloc[:,2] = daily_df.iloc[:,2].str.replace('\xa0F','')
daily_df.iloc[:,3] = daily_df.iloc[:,3].str.replace('\xa0%','')
daily_df.iloc[:,5] = daily_df.iloc[:,5].str.replace('\xa0mph','')
daily_df.iloc[:,6] = daily_df.iloc[:,6].str.replace('\xa0mph','')
daily_df.iloc[:,7] = daily_df.iloc[:,7].str.replace('\xa0in','')
daily_df.iloc[:,8] = daily_df.iloc[:,8].str.replace('\xa0in','')
#daily_df.iloc[:,9] = daily_df.iloc[:,9].str.replace(' in','') # this is missing in Jan 2020

# %%
daily_df
# Out:
#        Time Temperature(F) Dew Point(F) Humidity(%) Wind Wind Speed(mph)  \
# 0   6:54 PM             76           66          71    S              12
# 1   7:54 PM             75           67          76    S              12
# 2   9:54 PM             75           67          76   SW              10
# 3  10:54 PM             74           67          79  WSW              10
#
#   Wind Gust(mph) Pressure(in) Precip.(in)      Condition
# 0              0        29.99         0.0           Fair
# 1              0        29.99         0.0           Fair
# 2              0        29.99         0.0           Fair
# 3              0        30.00         0.0  Partly Cloudy

# %%
weather = pd.DataFrame()
weather = pd.concat([weather,daily_df])

# %%
weather.head()
# Out:
#        Time Temperature(F) Dew Point(F) Humidity(%) Wind Wind Speed(mph)  \
# 0   6:54 PM             76           66          71    S              12
# 1   7:54 PM             75           67          76    S              12
# 2   9:54 PM             75           67          76   SW              10
# 3  10:54 PM             74           67          79  WSW              10
#
#   Wind Gust(mph) Pressure(in) Precip.(in)      Condition
# 0              0        29.99         0.0           Fair
# 1              0        29.99         0.0           Fair
# 2              0        29.99         0.0           Fair
# 3              0        30.00         0.0  Partly Cloudy

# %% [markdown]
# ## Perform Mass Scraping
#
# put the above code into a function and mass scrape

# %%
import sys
import wget
from pathlib import Path
from fastai.imports import *
import requests
from bs4 import BeautifulSoup
from selenium import webdriver 
from datetime import datetime, date
import time
import pandas as pd

# %%
# set path to chromedriver
driver_path = "./chrome_driver/chromedriver"
browser = webdriver.Chrome(driver_path)

# %%
# define date range
start_date = datetime(2019, 1, 1)
stop_date = datetime(2019, 6, 10)
date_range = pd.date_range(start_date, stop_date).strftime('%Y-%m-%d')

# %%
weather_2016 = pd.DataFrame()

for date in date_range:
    # obtain daily weather dataframe
    daily_df, div_table = get_data_n_soup(date)
    # get the unit
    units = get_unit(div_table)
    
    #if daily_df.bool() == 0 or div_table.bool() == 0:
    #    print (f'Misiing data on {date}')
    #    continue
    
    # add the unit into the column names
    daily_df.columns = daily_df.columns + units
    
    print(f'Finish obtaining data on {date}')
    #combine the weather for each day
    weather_2016 = pd.concat([weather_2016,daily_df], axis=0, join='outer')
    print(len(weather_2016))
    
#save weather dataframe
weather_2016.to_csv('data/raw/weather/weather_2019_v1.csv')
# Out:
# Finish obtaining data on 2019-01-01
# 29
# Finish obtaining data on 2019-01-02
# 53
# Finish obtaining data on 2019-01-03
# 82
# Finish obtaining data on 2019-01-04
# 106
# Finish obtaining data on 2019-01-05
# 144
# Finish obtaining data on 2019-01-06
# 168
# Finish obtaining data on 2019-01-07
# 192
# Finish obtaining data on 2019-01-08
# 232
# Finish obtaining data on 2019-01-09
# 267
# Finish obtaining data on 2019-01-10
# 291
# Finish obtaining data on 2019-01-11
# 313
# Finish obtaining data on 2019-01-12
# 336
# Finish obtaining data on 2019-01-13
# 361
# Finish obtaining data on 2019-01-14
# 386
# Finish obtaining data on 2019-01-15
# 409
# Finish obtaining data on 2019-01-16
# 433
# Finish obtaining data on 2019-01-17
# 457
# Finish obtaining data on 2019-01-18
# 480
# Finish obtaining data on 2019-01-19
# 512
# Finish obtaining data on 2019-01-20
# 563
# Finish obtaining data on 2019-01-21
# 590
# Finish obtaining data on 2019-01-22
# 614
# Finish obtaining data on 2019-01-23
# 641
# Finish obtaining data on 2019-01-24
# 675
# Finish obtaining data on 2019-01-25
# 701
# Finish obtaining data on 2019-01-26
# 725
# Finish obtaining data on 2019-01-27
# 748
# Finish obtaining data on 2019-01-28
# 773
# Finish obtaining data on 2019-01-29
# 806
# Finish obtaining data on 2019-01-30
# 842
# Finish obtaining data on 2019-01-31
# 866
# Finish obtaining data on 2019-02-01
# 890
# Finish obtaining data on 2019-02-02
# 914
# Finish obtaining data on 2019-02-03
# 938
# Finish obtaining data on 2019-02-04
# 962
# Finish obtaining data on 2019-02-05
# 986
# Finish obtaining data on 2019-02-06
# 1016
# Finish obtaining data on 2019-02-07
# 1056
# Finish obtaining data on 2019-02-08
# 1086
# Finish obtaining data on 2019-02-09
# 1109
# Finish obtaining data on 2019-02-10
# 1133
# Finish obtaining data on 2019-02-11
# 1155
# Finish obtaining data on 2019-02-12
# 1197
# Finish obtaining data on 2019-02-13
# 1238
# Finish obtaining data on 2019-02-14
# 1262
# Finish obtaining data on 2019-02-15
# 1296
# Finish obtaining data on 2019-02-16
# 1321
# Finish obtaining data on 2019-02-17
# 1344
# Finish obtaining data on 2019-02-18
# 1401
# Finish obtaining data on 2019-02-19
# 1425
# Finish obtaining data on 2019-02-20
# 1453
# Finish obtaining data on 2019-02-21
# 1490
# Finish obtaining data on 2019-02-22
# 1514
# Finish obtaining data on 2019-02-23
# 1538
# Finish obtaining data on 2019-02-24
# 1583
# Finish obtaining data on 2019-02-25
# 1611
# Finish obtaining data on 2019-02-26
# 1633
# Finish obtaining data on 2019-02-27
# 1662
# Finish obtaining data on 2019-02-28
# 1696
# Finish obtaining data on 2019-03-01
# 1720
# Finish obtaining data on 2019-03-02
# 1754
# Finish obtaining data on 2019-03-03
# 1783
# Finish obtaining data on 2019-03-04
# 1827
# Finish obtaining data on 2019-03-05
# 1851
# Finish obtaining data on 2019-03-06
# 1875
# Finish obtaining data on 2019-03-07
# 1899
# Finish obtaining data on 2019-03-08
# 1923
# Finish obtaining data on 2019-03-09
# 1948
# Finish obtaining data on 2019-03-10
# 1989
# Finish obtaining data on 2019-03-11
# 2016
# Finish obtaining data on 2019-03-12
# 2040
# Finish obtaining data on 2019-03-13
# 2063
# Finish obtaining data on 2019-03-14
# 2087
# Finish obtaining data on 2019-03-15
# 2123
# Finish obtaining data on 2019-03-16
# 2149
# Finish obtaining data on 2019-03-17
# 2173
# Finish obtaining data on 2019-03-18
# 2197
# Finish obtaining data on 2019-03-19
# 2221
# Finish obtaining data on 2019-03-20
# 2244
# Finish obtaining data on 2019-03-21
# 2268
# Finish obtaining data on 2019-03-22
# 2299
# Finish obtaining data on 2019-03-23
# 2335
# Finish obtaining data on 2019-03-24
# 2358
# Finish obtaining data on 2019-03-25
# 2383
# Finish obtaining data on 2019-03-26
# 2407
# Finish obtaining data on 2019-03-27
# 2431
# Finish obtaining data on 2019-03-28
# 2455
# Finish obtaining data on 2019-03-29
# 2478
# Finish obtaining data on 2019-03-30
# 2505
# Finish obtaining data on 2019-03-31
# 2535
# Finish obtaining data on 2019-04-01
# 2558
# Finish obtaining data on 2019-04-02
# 2581
# Finish obtaining data on 2019-04-03
# 2611
# Finish obtaining data on 2019-04-04
# 2635
# Finish obtaining data on 2019-04-05
# 2659
# Finish obtaining data on 2019-04-06
# 2694
# Finish obtaining data on 2019-04-07
# 2717
# Finish obtaining data on 2019-04-08
# 2749
# Finish obtaining data on 2019-04-09
# 2781
# Finish obtaining data on 2019-04-10
# 2807
# Finish obtaining data on 2019-04-11
# 2831
# Finish obtaining data on 2019-04-12
# 2860
# Finish obtaining data on 2019-04-13
# 2888
# Finish obtaining data on 2019-04-14
# 2917
# Finish obtaining data on 2019-04-15
# 2955
# Finish obtaining data on 2019-04-16
# 2979
# Finish obtaining data on 2019-04-17
# 3003
# Finish obtaining data on 2019-04-18
# 3029
# Finish obtaining data on 2019-04-19
# 3057
# Finish obtaining data on 2019-04-20
# 3090
# Finish obtaining data on 2019-04-21
# 3124
# Finish obtaining data on 2019-04-22
# 3172
# Finish obtaining data on 2019-04-23
# 3209
# Finish obtaining data on 2019-04-24
# 3236
# Finish obtaining data on 2019-04-25
# 3260
# Finish obtaining data on 2019-04-26
# 3301
# Finish obtaining data on 2019-04-27
# 3333
# Finish obtaining data on 2019-04-28
# 3357
# Finish obtaining data on 2019-04-29
# 3381
# Finish obtaining data on 2019-04-30
# 3416
# Finish obtaining data on 2019-05-01
# 3441
# Finish obtaining data on 2019-05-02
# 3475
# Finish obtaining data on 2019-05-03
# 3510
# Finish obtaining data on 2019-05-04
# 3550
# Finish obtaining data on 2019-05-05
# 3577
# Finish obtaining data on 2019-05-06
# 3608
# Finish obtaining data on 2019-05-07
# 3634
# Finish obtaining data on 2019-05-08
# 3659
# Finish obtaining data on 2019-05-09
# 3683
# Finish obtaining data on 2019-05-10
# 3709
# Finish obtaining data on 2019-05-11
# 3737
# Finish obtaining data on 2019-05-12
# 3764
# Finish obtaining data on 2019-05-13
# 3799
# Finish obtaining data on 2019-05-14
# 3838
# Finish obtaining data on 2019-05-15
# 3870
# Finish obtaining data on 2019-05-16
# 3894
# Finish obtaining data on 2019-05-17
# 3920
# Finish obtaining data on 2019-05-18
# 3944
# Finish obtaining data on 2019-05-19
# 3973
# Finish obtaining data on 2019-05-20
# 4004
# Finish obtaining data on 2019-05-21
# 4027
# Finish obtaining data on 2019-05-22
# 4051
# Finish obtaining data on 2019-05-23
# 4078
# Finish obtaining data on 2019-05-24
# 4106
# Finish obtaining data on 2019-05-25
# 4130
# Finish obtaining data on 2019-05-26
# 4156
# Finish obtaining data on 2019-05-27
# 4183
# Finish obtaining data on 2019-05-28
# 4216
# Finish obtaining data on 2019-05-29
# 4244
# Finish obtaining data on 2019-05-30
# 4277
# Finish obtaining data on 2019-05-31
# 4304
# Finish obtaining data on 2019-06-01
# 4342
# Finish obtaining data on 2019-06-02
# 4381
# Finish obtaining data on 2019-06-03
# 4405
# Finish obtaining data on 2019-06-04
# 4429
# Finish obtaining data on 2019-06-05
# 4454
# Finish obtaining data on 2019-06-06
# 4488
# Finish obtaining data on 2019-06-07
# 4512
# Finish obtaining data on 2019-06-08
# 4536
# Finish obtaining data on 2019-06-09
# 4560
# Finish obtaining data on 2019-06-10
# 4588

# %%
#sometimes the for loop stop in the middle, so save the obtained data here
weather_2016.to_csv('data/raw/weather/weather_2019_v1.csv')

# %%
def get_data_n_soup(date_str):
    ''' Input: date in string
    - Ask Selenium to open the website, and execute inner javascript.
    - Parse data into beautifulsoup object and look for the hourly table
    - Parse the table into a panda dataframe
    - remove the unit 
    - add date column
    
    return: daily weather dataframe and beauitfulsoup object of that table
    '''
    # the weather station to be used (station KBOS at airport)
    url=f'https://www.wunderground.com/history/daily/us/ma/boston/KBOS/date/{date_str}'
    
    flag = True
    while flag:
        browser.get(url)
        time.sleep(10)
        innerhtml= browser.execute_script("return document.body.innerHTML")
        soup = BeautifulSoup(innerhtml)
        time.sleep(2)
        if len(soup.find_all(attrs={"class":"observation-table ng-star-inserted"}))>0:
            flag = False
    
    div_table=soup.find_all(attrs={"class":"observation-table ng-star-inserted"})[0]
    daily_df = pd.read_html(str(div_table))[0]
    #else:
    #    return 0,0
    
    # clean up data
    daily_df.iloc[:,1] = daily_df.iloc[:,1].str.replace('\xa0F','')
    daily_df.iloc[:,2] = daily_df.iloc[:,2].str.replace('\xa0F','')
    daily_df.iloc[:,3] = daily_df.iloc[:,3].str.replace('\xa0%','')
    daily_df.iloc[:,5] = daily_df.iloc[:,5].str.replace('\xa0mph','')
    daily_df.iloc[:,6] = daily_df.iloc[:,6].str.replace('\xa0mph','')
    daily_df.iloc[:,7] = daily_df.iloc[:,7].str.replace('\xa0in','')
    daily_df.iloc[:,8] = daily_df.iloc[:,8].str.replace('\xa0in','')
    #daily_df.iloc[:,9] = daily_df.iloc[:,9].str.replace(' in','') # this is missing in Jan 2020
    
    # add date columns
    daily_df['date'] = pd.to_datetime(date + ' ' +daily_df['Time'], format="%Y-%m-%d %I:%M %p")
    return daily_df, div_table

# %%
def get_unit(div_table):
    ''' stripe unit from the weather table
    columns that do not have unit get empty string 
    '''
    #if div_table == 0: return 0
    trow = div_table.tbody.find_all('tr')
    #stripping unit
    f_row = trow[0]
    units=[]
    for unit_cell in f_row.find_all(class_="wu-label"):
        unit = ''.join(string for string in unit_cell.stripped_strings)
        units.append(r'('+unit+r')')
    units.insert(0, '')
    units.insert(4, '')
    units.append('')
    units.append('')
    return units
